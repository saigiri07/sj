# %%
import numpy as np
import pandas as pd

# %%
#Creating a DataFrame from a given dictionary

data = {
    'ID' : np.arange(1,1000001),
    'Value' : np.random.rand(1000000),
    'Category' : np.random.choice(['A','B','C','D'],size=1000000)
}

# %%
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#    ID     Value Category
# 0   1  0.169705        C
# 1   2  0.095455        B
# 2   3  0.419695        B
# 3   4  0.178447        D
# 4   5  0.727369        D
# 5   6  0.710198        D
# 6   7  0.478706        C
# 7   8  0.411243        B
# 8   9  0.243961        A
# 9  10  0.932664        D

# %%
df['Value']
# Out:
# 0         0.169705
# 1         0.095455
# 2         0.419695
# 3         0.178447
# 4         0.727369
#             ...
# 999995    0.388192
# 999996    0.019076
# 999997    0.808089
# 999998    0.352690
# 999999    0.800799
# Name: Value, Length: 1000000, dtype: float64

# %%
'''Modify columns in the DataFrame with names (ID number, Random value, Choice) and show output
for first five rows.'''

df.rename(columns={'ID':'ID Number','Value':'Random Value','Category':'Choice'},inplace=True)

# %%
df.head(5)
# Out:
#    ID Number  Random Value Choice
# 0          1      0.169705      C
# 1          2      0.095455      B
# 2          3      0.419695      B
# 3          4      0.178447      D
# 4          5      0.727369      D

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d0a81e12-5530-4f61-b503-3ee57118c931" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0a81e12-5530-4f61-b503-3ee57118c931">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_csv('data.csv')
df2
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df2.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df2.isnull().value_counts()
# Out:
# Duration  Pulse  Maxpulse  Calories
# False     False  False     False       164
#                            True          5
# Name: count, dtype: int64

# %%
#Replace the null values with the mean
df2.fillna(df2.mean(),inplace=True)

# %%
df2.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df2[['Duration','Pulse']].min()
# Out:
# Duration    15
# Pulse       80
# dtype: int64

# %%
df2[['Duration','Pulse']].max()
# Out:
# Duration    300
# Pulse       159
# dtype: int64

# %%
df2[['Duration','Pulse']].mean()
# Out:
# Duration     63.846154
# Pulse       107.461538
# dtype: float64

# %%
df2[df2['Calories'].between(500,1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#Filter the dataframe to select the rows with calories values > 500 and pulse < 100
df2[(df2['Calories']>500) & (df2['Pulse']<100)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = df2[['Duration','Pulse','Calories']]
df_modified.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %%
df2.drop(columns=['Maxpulse'])
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df2['Calories'].astype(int)
# Out:
# 0      409
# 1      479
# 2      340
# 3      282
# 4      406
#       ...
# 164    290
# 165    300
# 166    310
# 167    320
# 168    330
# Name: Calories, Length: 169, dtype: int64

# %%
df2[['Duration','Calories']].plot(kind='scatter',x='Duration',y='Calories')
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)

student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'VI', 'VI', 'V', 'VI', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    # Corrected: Removed the extra date to match the length of other lists (6 elements)
    'date_Of_Birth': ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
}, index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])

print("Original DataFrame:")
print(student_data)

print("\nSplit the said data on school_code, class wise:")
result = student_data.groupby(['school_code', 'class'])

for name, group in result:
    print("\nGroup:")
    print(name)  # 'name' here refers to the group key (e.g., ('s001', 'V'))
    print(group)
# Out:
# Original DataFrame:
#    school_code class            name date_Of_Birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
# S2        s002    VI    Gino Mcneill    17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes    16/02/1999   13     186      33
# S4        s001     V    Eesha Hinton    25/09/1998   13     167      30
# S5        s002    VI    Gino Mcneill    11/05/2002   14     151      31
# S6        s004    VI    David Parkes    15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4
#
# Split the said data on school_code, class wise:
#
# Group:
# ('s001', 'V')
#    school_code class            name date_Of_Birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
# S4        s001     V    Eesha Hinton    25/09/1998   13     167      30
#
#     address
# S1  street1
# S4  street1
#
# ...
